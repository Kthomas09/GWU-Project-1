# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import requests
import json
import scipy.stats as st

# %%
mental_health=pd.read_csv("data_resources/2020IndicatorsofDepression.csv")
mental_health
# Out:
#                                               Indicator              Group  \
# 0                       Symptoms of Depressive Disorder  National Estimate
# 1                       Symptoms of Depressive Disorder             By Age
# 2                       Symptoms of Depressive Disorder             By Age
# 3                       Symptoms of Depressive Disorder             By Age
# 4                       Symptoms of Depressive Disorder             By Age
# ...                                                 ...                ...
# 2515  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2516  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2517  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2518  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 2519  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
# ...

# %%
state_df = mental_health.loc[mental_health['Group']=='By State']
state_df.head()
# Out:
#                           Indicator     Group       State    Subgroup  Week  \
# 19  Symptoms of Depressive Disorder  By State     Alabama     Alabama     1
# 20  Symptoms of Depressive Disorder  By State      Alaska      Alaska     1
# 21  Symptoms of Depressive Disorder  By State     Arizona     Arizona     1
# 22  Symptoms of Depressive Disorder  By State    Arkansas    Arkansas     1
# 23  Symptoms of Depressive Disorder  By State  California  California     1
#
#         Week Label  Value  Low CI  High CI Confidence Interval Quartile range
# 19  Apr 23 - May 5   18.6    14.6     23.1         14.6 - 23.1    16.5 - 20.7
# 20  Apr 23 - May 5   19.2    16.8     21.8         16.8 - 21.8    16.5 - 20.7
# 21  Apr 23 - May 5   22.4    19.4     25.5         19.4 - 25.5    22.2 - 24.0
# 22  Apr 23 - May 5   26.6    22.3     31.3         22.3 - 31.3    24.1 - 28.7
# 23  Apr 23 - May 5   25.4    22.5     28.6         22.5 - 28.6    24.1 - 28.7

# %%
age_df = mental_health.loc[mental_health['Group']=='By Age']
age_df.head()
# Out:
#                          Indicator   Group          State       Subgroup  \
# 1  Symptoms of Depressive Disorder  By Age  United States  18 - 29 years
# 2  Symptoms of Depressive Disorder  By Age  United States  30 - 39 years
# 3  Symptoms of Depressive Disorder  By Age  United States  40 - 49 years
# 4  Symptoms of Depressive Disorder  By Age  United States  50 - 59 years
# 5  Symptoms of Depressive Disorder  By Age  United States  60 - 69 years
#
#    Week      Week Label  Value  Low CI  High CI Confidence Interval  \
# 1     1  Apr 23 - May 5   32.7    30.2     35.2         30.2 - 35.2
# 2     1  Apr 23 - May 5   25.7    24.1     27.3         24.1 - 27.3
# 3     1  Apr 23 - May 5   24.8    23.3     26.2         23.3 - 26.2
# 4     1  Apr 23 - May 5   23.2    21.5     25.0         21.5 - 25.0
# 5     1  Apr 23 - May 5   18.4    17.0     19.7         17.0 - 19.7
#
#   Quartile range
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN

# %%
Gender_df = mental_health.loc[mental_health['Group']=='By Gender']
Gender_df.head()
# Out:
#                                              Indicator      Group  \
# 8                      Symptoms of Depressive Disorder  By Gender
# 9                      Symptoms of Depressive Disorder  By Gender
# 78                        Symptoms of Anxiety Disorder  By Gender
# 79                        Symptoms of Anxiety Disorder  By Gender
# 148  Symptoms of Anxiety Disorder or Depressive Dis...  By Gender
#
#              State Subgroup  Week      Week Label  Value  Low CI  High CI  \
# 8    United States     Male     1  Apr 23 - May 5   20.8    19.6     22.0
# 9    United States   Female     1  Apr 23 - May 5   26.1    25.2     27.1
# 78   United States     Male     1  Apr 23 - May 5   26.1    24.7     27.5
# 79   United States   Female     1  Apr 23 - May 5   35.4    34.5     36.3
# 148  United States     Male     1  Apr 23 - May 5   31.0    29.6     32.3
#
#     Confidence Interval Quartile range
# 8           19.6 - 22.0            NaN
# 9           25.2 - 27.1            NaN
# ...

# %%
week_label=mental_health["Week Label"]
week_label.unique()
# Out:
# array(['Apr 23 - May 5', 'May 7 - May 12', 'May 14 - May 19',
#        'May 21 - May 26', 'May 28 - June 2', 'June 4 - June 9',
#        'June 11 - June 16', 'June 18 - June 23', 'June 25 - June 30',
#        'July 2 - July 7', 'July 9 - July 14', 'July 16 - July 21'],
#       dtype=object)

# %%
covid_df=pd.read_csv("data_resources/Covid_Data.csv")
covid_df
# Out:
#           date state  positive  negative  pending  hospitalizedCurrently  \
# 0     20200806    AK    4223.0  257349.0      NaN                   42.0
# 1     20200806    AL   96592.0  643192.0      NaN                 1575.0
# 2     20200806    AR   47028.0  492808.0      NaN                  514.0
# 3     20200806    AS       0.0    1396.0      NaN                    NaN
# 4     20200806    AZ  183647.0  812217.0      NaN                 1879.0
# ...        ...   ...       ...       ...      ...                    ...
# 8636  20200126    WA       2.0       0.0      NaN                    NaN
# 8637  20200125    WA       2.0       0.0      NaN                    NaN
# 8638  20200124    WA       2.0       0.0      NaN                    NaN
# 8639  20200123    WA       2.0       0.0      NaN                    NaN
# 8640  20200122    WA       2.0       0.0      NaN                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
covid_19_df=covid_df.rename(columns={"state":"State"},inplace= False)
covid_19_df
# Out:
#           date State  positive  negative  pending  hospitalizedCurrently  \
# 0     20200806    AK    4223.0  257349.0      NaN                   42.0
# 1     20200806    AL   96592.0  643192.0      NaN                 1575.0
# 2     20200806    AR   47028.0  492808.0      NaN                  514.0
# 3     20200806    AS       0.0    1396.0      NaN                    NaN
# 4     20200806    AZ  183647.0  812217.0      NaN                 1879.0
# ...        ...   ...       ...       ...      ...                    ...
# 8636  20200126    WA       2.0       0.0      NaN                    NaN
# 8637  20200125    WA       2.0       0.0      NaN                    NaN
# 8638  20200124    WA       2.0       0.0      NaN                    NaN
# 8639  20200123    WA       2.0       0.0      NaN                    NaN
# 8640  20200122    WA       2.0       0.0      NaN                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
#merge mental health data with covid data
merged_data = pd.merge(state_df, covid_19_df,how ="left", on=['State'])
merged_data
# Out:
#                                               Indicator     Group  \
# 0                       Symptoms of Depressive Disorder  By State
# 1                       Symptoms of Depressive Disorder  By State
# 2                       Symptoms of Depressive Disorder  By State
# 3                       Symptoms of Depressive Disorder  By State
# 4                       Symptoms of Depressive Disorder  By State
# ...                                                 ...       ...
# 1831  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 1832  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 1833  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 1834  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 1835  Symptoms of Anxiety Disorder or Depressive Dis...  By State
#
#               State       Subgroup  Week         Week Label  Value  Low CI  \
# 0           Alabama        Alabama     1     Apr 23 - May 5   18.6    14.6
# ...

# %%
merged_data.drop_duplicates("State")
merged_data
