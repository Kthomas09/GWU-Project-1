# %%
import pandas as pd

# %%
df = pd.read_csv("data_resources/Covid_Data.csv")
df
# Out:
#           date state  positive  negative  pending  hospitalizedCurrently  \
# 0     20200806    AK    4223.0  257349.0      NaN                   42.0
# 1     20200806    AL   96592.0  643192.0      NaN                 1575.0
# 2     20200806    AR   47028.0  492808.0      NaN                  514.0
# 3     20200806    AS       0.0    1396.0      NaN                    NaN
# 4     20200806    AZ  183647.0  812217.0      NaN                 1879.0
# ...        ...   ...       ...       ...      ...                    ...
# 8636  20200126    WA       2.0       0.0      NaN                    NaN
# 8637  20200125    WA       2.0       0.0      NaN                    NaN
# 8638  20200124    WA       2.0       0.0      NaN                    NaN
# 8639  20200123    WA       2.0       0.0      NaN                    NaN
# 8640  20200122    WA       2.0       0.0      NaN                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# ...

# %%
median_deaths=df["deathConfirmed"].median()
median_deaths
# Out:
# 813.0

# %%
#pre_covid=pd.read_csv("data_resources/2017PreCovidDisorders.csv")
#pre_covid
# Out:
#                                       measure     location   sex       age  \
# 0      DALYs (Disability-Adjusted Life Years)      Germany  Both  All Ages
# 1      DALYs (Disability-Adjusted Life Years)      Germany  Both  All Ages
# 2      DALYs (Disability-Adjusted Life Years)      Germany  Both  All Ages
# 3      DALYs (Disability-Adjusted Life Years)  Philippines  Both  All Ages
# 4      DALYs (Disability-Adjusted Life Years)  Philippines  Both  All Ages
# ...                                       ...          ...   ...       ...
# 16111  DALYs (Disability-Adjusted Life Years)       Bhutan  Both  All Ages
# 16112  DALYs (Disability-Adjusted Life Years)       Bhutan  Both  All Ages
# 16113  DALYs (Disability-Adjusted Life Years)       Bhutan  Both  All Ages
# 16114  DALYs (Disability-Adjusted Life Years)       Bhutan  Both  All Ages
# 16115  DALYs (Disability-Adjusted Life Years)       Bhutan  Both  All Ages
#
# ...

# %%
#depression_indicators=pd.read_csv("data_resources/2020IndicatorsofDepression.csv")
#depression_indicators.head()
# Out:
#                          Indicator              Group          State  \
# 0  Symptoms of Depressive Disorder  National Estimate  United States
# 1  Symptoms of Depressive Disorder             By Age  United States
# 2  Symptoms of Depressive Disorder             By Age  United States
# 3  Symptoms of Depressive Disorder             By Age  United States
# 4  Symptoms of Depressive Disorder             By Age  United States
#
#         Subgroup  Week      Week Label  Value  Low CI  High CI  \
# 0  United States     1  Apr 23 - May 5   23.5    22.7     24.3
# 1  18 - 29 years     1  Apr 23 - May 5   32.7    30.2     35.2
# 2  30 - 39 years     1  Apr 23 - May 5   25.7    24.1     27.3
# 3  40 - 49 years     1  Apr 23 - May 5   24.8    23.3     26.2
# 4  50 - 59 years     1  Apr 23 - May 5   23.2    21.5     25.0
#
#   Confidence Interval Quartile range
# 0         22.7 - 24.3            NaN
# 1         30.2 - 35.2            NaN
# 2         24.1 - 27.3            NaN
# ...
